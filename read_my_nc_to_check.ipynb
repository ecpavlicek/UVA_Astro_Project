# %%
import xarray as xr
from pathlib import Path

# %%
current_directory = Path.cwd()
red_file_path = current_directory / 'red_spectra.nc'
blue_file_path = current_directory / 'blue_spectra.nc'

# %%
red_dataset = xr.open_dataset(red_file_path)
blue_dataset = xr.open_dataset(blue_file_path)

# %%
red_dataset
